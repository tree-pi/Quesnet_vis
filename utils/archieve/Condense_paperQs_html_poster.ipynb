# %%
# condense paper html generation 

# The program aims to generate the html file from the 
# condensed topic graph

import networkx as nx 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json 
import pickle
import os

from IPython.core.debugger import set_trace

# %%
fname = ''#'fullQs_qnet.json'

# %%
fdir = 'jscode/poster/pickle/' # designed for the poster 

pickfile=open(fdir+'nodeQs_qnet3.p','rb')
mydict = pickle.load(pickfile)
pickfile.close()

# divde the node and link 
[dic_node, dic_link, others] = mydict

# graph initialization 
topic_graph = nx.Graph()
# html json initialization
ht_nodes = []
ht_edges = []


# add nodes into the graph
(row, col) = dic_node.shape

def wrap_by_word(s, n):
    '''returns a string where \\n is inserted between every n words'''
    a = s.split()
    ret = ''
    for i in range(0, len(a), n):
        ret += ' '.join(a[i:i+n]) + '\n'

    return ret


for index in range(row):
    nd_id = dic_node.iloc[index]['id']
    nd_label = dic_node.iloc[index]['label']
    nd_type = dic_node.iloc[index]['type']
    nd_content = dic_node.iloc[index]['content']
    nd_speaker = dic_node.iloc[index]['speaker']
    
    if nd_type == 'Answer':
        nd_color = 'blue'
        nd_size = 6
    elif nd_type == 'Question':
        nd_color = 'dodgerblue'
        nd_size = 8
    else:
        nd_color = 'tomato'
        nd_size = 10
    # shrink the label
    if nd_type == 'Question' or nd_type == 'Answer':        
        nd_label1 = wrap_by_word(nd_label,3)
    else:
        nd_label1 = nd_label    
        
    ht_nodes.append({'id':nd_id, 'label': nd_label1, 'type':nd_type,
                     'color': nd_color, 'size':nd_size, 'font':{'vadjust':'15'},
                     'speaker':nd_speaker, 'content':nd_content})

# add link into the graph 
(row, col) = dic_link.shape

for index in range(row):
    lk_id = dic_link.iloc[index]['id']
    lk_from = dic_link.iloc[index]['start']
    lk_to = dic_link.iloc[index]['end']
    lk_label = dic_link.iloc[index]['label']
    
    ht_edges.append({'from':lk_from, 'to': lk_to, 'label': lk_label, 'color':{'inherit':'to'},
                     'font':{'align':'middle'},
                     'arrows':'to'})

# export 

# save the json import version 
"""
data = []
data = {"nodes":ht_nodes,"edges":ht_edges}
with open('jscode/poster/json/fullQs_qnet1.json', 'w') as outfile:  
    json.dump(data, outfile)"""

# save the complete html version
with open('jscode/poster/json/nodeQs_qnet3.txt', 'w') as outfile:  
    json.dump(ht_nodes, outfile)
with open('jscode/poster/json/edgeQs_qnet3.txt', 'w') as outfile:  
    json.dump(ht_edges, outfile)

# %%
mydict
# Out:
# [   content      id                                              label  level  \
#  0           q23475       What is the task that is difficult to solve?      0
#  1           q48222  What are the limitations from previous solutions?      1
#  2           q49928                  What is the algorithm we propose?      1
#  3           q81586                                What is the reward?      2
#  4           q98892                      What is the training process?      2
#  5           q56866                                What is the policy?      2
#  6           q77092  How is this algorithm different from previous ...      3
#  7            q5559                                  What is the task?      1
#  8           q16453                            Why choosing this task?      2
#  9           q66175                       How good is the performance?      1
#  10          q23290                              What to compare with?      2
#  11          q92887  How is the performance when the environment ch...      3
#  12          q25928     How is the performance when the model changes?      3
#  13          q51120                                   How to evaluate?      2
#  14          q69546                  What are the critical parameters?      2
#  15          q67193                  Can it generalize to other tasks?      1
#
#      speaker           type
#  0   Ep26381  Root question
#  1   Ep26381       Question
#  2   Ep26381       Question
#  3   Ep26381       Question
#  4   Ep26381       Question
#  5   Ep26381       Question
#  6   Ep26381       Question
#  7   Ep26381       Question
#  8   Ep26381       Question
#  9   Ep26381       Question
#  10  Ep26381       Question
#  11  Ep26381       Question
#  12  Ep26381       Question
#  13  Ep26381       Question
#  14  Ep26381       Question
#  15  Ep26381       Question  ,        end      id          label   start
#  0   q48222  l33815                 q23475
#  1   q49928   l9074                 q23475
#  2   q81586   l9419  specification  q49928
#  3   q98892  l29572  specification  q49928
#  4   q56866  l75997  specification  q49928
#  5   q77092  l14309                 q56866
#  6    q5559   l4030                 q23475
#  7   q16453  l72028                  q5559
#  8   q66175  l96939                 q23475
#  9   q23290  l29907                 q66175
#  10  q92887  l43341                 q23290
#  11  q25928  l94097                 q23290
#  12  q51120  l28838                 q66175
#  13  q69546  l68969                 q66175
#  14  q67193   l1652                 q23475, [['q81586', 'q98892', 'q56866']]]

# %% [markdown]
# 1-[read from text](#from_text)
# 2-[form data structure](#form_datastructure)
# 3-[hand input](#hand_input)

# %% [markdown]
# Some designing notes:
# - id. **Answers can have the same ids (plotted in the same place) while questions do not**. Some questions will be repeated in different contexts. Yet each answer is unique and the same answer should be regarded a same thing. Unless it's like really simple questions ("yes/no").

# %%
import numpy as np
import pandas as pd
import re
import pickle
import os

# %% [markdown]
# # from_text

# %% [markdown]
# temp: replace space to tabs to make sure the following reading works.

# %%
fname='what_is_love.txt'
refname = 'love_quesnet.txt'

# %%
with open(fname,'r') as f:
    content = f.readlines()
content = [x.strip('\n') for x in content] # remove whitespace at the end. keep the tab \t to mark level of question
for line in content:
    if line[0]==' ':
        line = line.replace('  ','\t')
    with open(refname, 'a') as wf:
        wf.write(line+'\n')

# %% [markdown]
# temp: for chinese text, switch the punctuations

# %%
for line in content:
    if line.find('？'):
        line = line.replace('？','?')
    if line.find('？'):
        line = line.replace('？','.')
    with open(refname, 'w') as wf:
        wf.write(line+'\n')

# %% [markdown]
# **TODO**: if there's more '\t' left out at the end of the line, will cause wrong level calculation. to get rid of that.

# %% [markdown]
# # form_datastructure

# %% [markdown]
# ## empirical_study_network
# Basic structure:
# ### questions
# - central question and specification questions and follow-up questions: research question
#
# ### statements
# - hypothesis: a guess to answer "what" questions. either follows a conceptual question or a prediction question. ** marks the support for the hypothesis. TODO: this "support" should be linked to other nodes.
#
# - proposal: a "how" proposal, usually means "how to answer the question above".
#
# - criticism: may follow a hypothesis or a design (proposal/operationalize) or a finding.
#
# - prediction: given a study design (either proposal or operationalize node), what are the predictions? will be followed by hypothesis nodes and finding nodes.
#
# ### answers
# - finding: an answer based on real study.
#
# - operational-def: a concrete "how" that has been implemeted by existing study. will be followed by predictions (random guesses) and findings (based on existing study).

# %%
fname='love_quesnet.txt'#'what_is_love.txt'
with open(fname,'r') as f:
    content = f.readlines()
content = [x.strip('\n') for x in content] # remove whitespace at the end. keep the tab \t to mark level of question

rootlv=0
root = content[0]
nodedist = {'id':['q%d'%np.random.randint(100000)],'label':[root],'feature':['Central question'],'content':[""],'reference':[""]}

rootlist = [[] for k in range(10)]
rootlist[rootlv] = nodedist['id'][0]
fullnet = []

for line in content[1:]:
    if len(line)<1: # skip empty lines
        continue
    if line[:2]=='##':#ending sign
        break
    edge = line[line.find('_')+1:line.rfind('_')]
    if len(edge)<1:
        print(node)
    node = line[line.rfind('_')+2:]
    
    if edge == 'finding' or edge =='operational-def':
        label = node[:node.find('.')]
        if node.find('[')>=0:
            content = node[node.find('.')+1:node.find('[')]
            reference = node[node.find('[')+1:node.find(']')]
        else:
            content = []
            reference = []
        if label not in nodedist['label']: # if an answer has appeared earlier (usually an entity?), should be represented as the same node.            
            nid = 'a%d'%np.random.randint(100000)
            nodedist['feature'].append('Answer')    
            nodedist['label'].append(label)
            nodedist['id'].append(nid)
            nodedist['content'].append(content)
            nodedist['reference'].append(reference)
            
        else:
            nid = nodedist['id'][nodedist['label'].index(label)]
    elif edge == 'follow-up' or edge =='specification':
        label = node[:(np.max([node.find('?'),node.find('.')])+1)]
        if node.find('[')>=0:
            content = node[node.find('?')+1:node.find('[')]
            reference = node[node.find('[')+1:node.find(']')]
        else:
            content = []
            reference = []
        nid = 'q%d'%np.random.randint(100000)
        nodedist['feature'].append('Question')
        nodedist['label'].append(label)
        nodedist['id'].append(nid)
        nodedist['content'].append(content)
        nodedist['reference'].append(reference)
    else: # proposal, hypothesis, criticism -- statements        
        label = node[:(np.max([node.find('?'),node.find('.')])+1)]
        if node.find('[')>=0:
            content = node[node.find('?')+1:node.find('[')]
            reference = node[node.find('[')+1:node.find(']')]
        else:
            content = []
            reference = []
        nid = 's%d'%np.random.randint(100000)
        nodedist['feature'].append('Statement')
        nodedist['label'].append(label)
        nodedist['id'].append(nid)
        nodedist['content'].append(content)
        nodedist['reference'].append(reference)
    
    level = int((len(line) - len(line.strip('\t')))/len('\t'))
    edgedict = {'start':rootlist[level-1],'end':nid,'label':edge,'id':'l%d'%np.random.randint(100000)}
    fullnet.append(edgedict)    
    rootlist[level]=nid
nodedf = pd.DataFrame(nodedist)
edgedf = pd.DataFrame(fullnet)  
filedir = 'database/'
#os.makedirs(filedir)
pickle.dump([nodedf,edgedf],open(filedir+'/love_chinese.p','bw'))

# %%
nodedf
# Out:
#                        content           feature      id  \
# 0                               Central question  q21616
# 1                           []         Statement  s59215
# 2                           []          Question  q30335
# 3                           []         Statement   s9191
# 4                           []          Question  q50517
# 5                           []         Statement  s26799
# 6                           []         Statement   s9333
# 7                           []         Statement  s15094
# 8                           []         Statement  s89190
# 9                           []         Statement   s4570
# 10                          []          Question  q51146
# 11                          []         Statement  s27534
# 12                          []         Statement  s41613
# 13                          []         Statement  s82086
# 14                          []          Question  q10351
# 15                          []         Statement  s64207
# 16                          []          Question  q17990
# 17                          []         Statement  s73548
# 18                          []         Statement  s57058
# 19                          []         Statement  s90346
# 20                          []         Statement  s55448
# 21                                        Answer  a65439
# 22                          []         Statement  s48345
# 23                          []         Statement  s39874
# 24                          []         Statement  s62727
# 25                                        Answer   a4870
# 26                          []          Question  q79402
# 27                          []          Question  q72859
# 28                          []          Question  q32792
# 29                          []         Statement  s84346
# 30                          []         Statement  s65061
# 31                          []         Statement  s69427
# 32                          []          Question  q47469
# 33                                        Answer  a76815
# 34                          []         Statement  s18458
# 35                          []          Question   q1758
# 36  注射催产素和加压素，看是否改变草原田鼠的择偶习惯.          Statement  s11520
# 37                                        Answer   a4434
# 38                          []          Question   q2760
# 39                          []         Statement  s46545
#
#                                               label             reference
# 0                                             爱是什么?
# 1                                     爱不带来物质回报，不功利.                    []
# 2                                         如何定义“功利”?                    []
# 3                           你可以付出，但别人不知道是你，你是否愿意付出?                    []
# 4                    是否付出是为了对方，还是只是享受付出的过程，如何区别这两者?                    []
# 5   如果可以用其他人代替这个人，那就不是爱（而是爱的这个人带给你的某些东西，比如“付出”的感觉）.                    []
# 6                             普世的爱，不对特定的人有关，难道不是爱吗?                    []
# 7          我给父母打电话，是分享我的事（为了自己）还是听他们的唠叨（为了他们），感受不同.                    []
# 8                                    爱是一种内部感受（愉悦感）.                    []
# 9                  如果可以用其它很多类似的东西替代，那就不是爱（爱的是外部激励）.                    []
# 10       外部动机是否一直在被内化?比如背单词，原本是为了获得奖励，但渐渐喜欢上了背单词本身.                    []
# 11                       爱是基于已有的经验和记忆，对某种特定的人产生了反应.                    []
# 12                            需要分离生理变化（性征发育、激素）的影响.                    []
# 13       找到特别人群（比如使用了hormone blocker的人），研究他们的爱有何不同.                    []
# 14                                    浪漫之爱的神经过程是什么?                    []
# 15                                刺激大脑，主观汇报，是否感受到爱?                    []
# 16                       汇报对某个人的爱，还是一种整体感觉而不针对与某个人?                    []
# 17                           不知道该刺激哪里；现有刺激的技术可能不成熟.                    []
# 18          跟踪爱情中的人，看主观”爱的感觉“的量表，同时找脑信号correlation.                    []
# 19                             不能给出causal relation.                    []
# 20                           呈现爱人的图片或其他信息，看大脑如何被激活.                    []
# 21                        看爱人照片和朋友照片，通过fMRI看脑激活有何不同       Aron et al 2005
# 22                                      大脑哪里应该会有激活?                    []
# 23                                          会有激素调节.                    []
# 24                         会有记忆脑区的区别（然而应该怎么区别?不确定）.                    []
# 25                                   诸多与奖赏回路相关的脑区活跃       Aron et al 2005
# 26                         如果一个人的爱不求回报，还会有奖赏回路的激活吗?                    []
# 27                              但是如果爱情刚刚开始，是否有这个奖赏?                    []
# 28                                   与生活其他的奖赏有什么关系?                    []
# 29      只是说爱和友情的区别是奖赏回路，但是爱和工作还有别的差异，比如社会性，比如温柔的感觉.                    []
# 30        应该比较爱人的照片和其它触发奖赏回路的刺激（比如美食照片），激发的反应差别在哪里.                    []
# 31                                    这到底是爱还是被爱的感觉?                    []
# 32                                     分手后的神经过程是什么?                    []
# 33                  找刚刚分手但还依然爱着的苦逼人来参与实验，看爱人照片和朋友照片           Fisher 2010
# 34                                      分手后会有不同的感受.                    []
# 35                              与伴侣持久的长期之爱，神经过程是什么?                    []
# 36                        注射催产素和加压素，看是否改变草原田鼠的择偶习惯.  Young and Wang, 2004
# 37                                    能阻止田鼠对固定伴侣的偏好  Young and Wang, 2004
# 38                               当这个激素消失后，会有什么行为变化?                    []
# 39          动物无法主观汇报爱情，所以动物研究永远无法理解人的爱情（只可以帮助理解择偶）.                    []

# %% [markdown]
# ## definition network

# %%
fname='love_quesnet.txt'#'what_is_love.txt'
with open(fname,'r') as f:
    content = f.readlines()
content = [x.strip('\n') for x in content] # remove whitespace at the end. keep the tab \t to mark level of question

rootlv=0
root = content[0]
nodedist = {'id':['qd%d'%np.random.randint(100000)],'label':[root],'feature':['Central question'],'content':[""],'reference':[""]}


rootlist = [[] for k in range(10)]
rootlist[rootlv] = nodedist['id'][0]
fullnet = []

for line in content[1:]:
    if len(line)<1: # skip empty lines
        continue
    if line[:2]=='##':#ending sign
        break
    edge = line[line.find('_')+1:line.rfind('_')]
    if len(edge)<1:
        print(node)
    node = line[line.rfind('_')+2:]
    
    if edge == 'answer':
        label = node[:node.find('.')]
        if node.find('[')>=0:
            content = node[node.find('.')+1:node.find('[')]
            reference = node[node.find('[')+1:node.find(']')]
        else:
            content = []
            reference = []
        if label not in nodedist['label']: # if an answer has appeared earlier (usually an entity?), should be represented as the same node.            
            nid = 'ad%d'%np.random.randint(100000)
            nodedist['feature'].append('Answer')    
            nodedist['label'].append(label)
            nodedist['id'].append(nid)
            nodedist['content'].append(content)
            nodedist['reference'].append(reference)
            
        else:
            nid = nodedist['id'][nodedist['label'].index(label)]
    elif edge == 'category' or 'study' or 'hypothesis':
        label = node
        if node.find('[')>=0:
            content = node[node.find('.')+1:node.find('[')]
            reference = node[node.find('[')+1:node.find(']')]
        else:
            content = []
            reference = []
        if label not in nodedist['label']: # if an answer has appeared earlier (usually an entity?), should be represented as the same node.            
            nid = 'ad%d'%np.random.randint(100000)
            nodedist['feature'].append('Answer')    
            nodedist['label'].append(label)
            nodedist['id'].append(nid)
            nodedist['content'].append(content)
            nodedist['reference'].append(reference)
    else:
        
        label = node[:(node.find('?')+1)]
        if node.find('[')>=0:
            content = node[node.find('?')+1:node.find('[')]
            reference = node[node.find('[')+1:node.find(']')]
        else:
            content = []
            reference = []
        nid = 'qd%d'%np.random.randint(100000)
        nodedist['feature'].append('Question')
        nodedist['label'].append(label)
        nodedist['id'].append(nid)
        nodedist['content'].append(content)
        nodedist['reference'].append(reference)
    
    level = int((len(line) - len(line.strip('\t')))/len('\t'))
    edgedict = {'start':rootlist[level-1],'end':nid,'label':edge,'id':'l%d'%np.random.randint(100000)}
    fullnet.append(edgedict)    
    rootlist[level]=nid
nodedf = pd.DataFrame(nodedist)
edgedf = pd.DataFrame(fullnet)  
filedir = 'database/'
#os.makedirs(filedir)
pickle.dump([nodedf,edgedf],open(filedir+'/love_chinese.p','bw'))

# %%
edgedf
# Out:
#         end      id           label    start
# 0   ad13358  l46889      hypothesis  qd90433
# 1   ad66362  l40326   specification  ad13358
# 2   ad14875  l15230  operationalize  ad13358
# 3   ad10702  l52463   specification  ad14875
# 4    ad1130  l55873          answer  ad10702
# 5   ad66799  l25151      hypothesis  qd90433
# 6   ad32456  l74935      hypothesis  qd90433
# 7   ad82294   l4322       follow-up  ad32456
# 8   ad67612  l46766        argument  ad32456
# 9   ad59993  l92625   specification  qd90433
# 10  ad47424  l29794  operationalize  ad59993
# 11  ad26586  l78745      hypothesis  ad59993
# 12  ad60819  l64696       criticize  ad26586
# 13  ad71881  l22927           study  ad26586
# 14  ad22640  l81185        argument  ad71881
# 15  ad60255  l30829           study  ad26586
# 16  ad40425  l69535         predict  ad60255
# 17  ad37356  l86309      hypothesis  ad40425
# 18  ad20587  l24249          answer  ad40425
# 19  ad96063  l57103        argument  ad20587
# 20  ad90789  l89731       follow-up  ad20587
# 21  ad63959  l35348       follow-up  ad20587
# 22  ad38713  l54063      hypothesis  ad63959
# 23  ad73986  l66568      hypothesis  ad59993
# 24  ad29677  l72085   specification  ad59993
# 25   ad7241  l60916   specification  ad59993
# 26  ad28347  l49733      hypothesis  ad60255
# 27  ad38967  l68693           study  ad59993
# 28  ad93146  l13727        argument  ad38967
# 29  ad57656  l87849       follow-up  ad38967
# 30  ad20799  l55426      hypothesis  ad59993
# 31  ad41468  l95352   specification  ad20799

# %%
nodedf
# Out:
#    content           feature       id  \
# 0           Central question  qd44803
# 1       []            Answer  ad25305
# 2       []            Answer  ad71754
# 3       []            Answer  ad76892
# 4       []            Answer  ad45764
# 5       []            Answer  ad86736
# 6       []            Answer  ad53838
# 7       []            Answer  ad32887
# 8       []            Answer  ad67206
# 9       []            Answer  ad23117
# 10      []            Answer  ad83376
# 11      []            Answer  ad15993
# 12      []            Answer  ad88025
# 13      []            Answer  ad69502
# 14      []            Answer  ad86893
# 15      []            Answer  ad79646
# 16      []            Answer  ad55814
# 17      []            Answer  ad94477
# 18      []            Answer  ad55601
# 19      []            Answer  ad62166
# 20      []            Answer  ad65210
# 21      []            Answer  ad45316
# 22      []            Answer  ad59501
# 23      []            Answer  ad92919
# 24      []            Answer  ad43764
# 25      []            Answer  ad25417
# 26      []            Answer  ad90363
# 27      []            Answer  ad56761
# 28      []            Answer  ad96247
# 29      []            Answer  ad35081
# 30      []            Answer  ad95548
# 31      []            Answer  ad69441
# 32      []            Answer  ad27898
#
#                                           label reference
# 0                                         爱是什么？
# 1                                 爱不带来物质回报，不功利。        []
# 2                              如何定义“功利”？为了性而爱呢？        []
# 3                       你可以付出，但别人不知道是你，你是否愿意付出？        []
# 4                   是否付出是为了对方，还是只是享受付出的过程？如何区别？        []
# 5                   我给父母打电话，是分享我的事还是听他们的唠叨，感受不同        []
# 6                                      爱是一种愉悦感。        []
# 7        如果其他人可以替代这个人，带来很多类似的东西，那就不是爱（爱的是外部激励）.        []
# 8                                 外部动机是否一直在被内化？        []
# 9                         普世的爱，不对特定的人有关，难道不是爱吗？        []
# 10                                浪漫之爱的神经过程是什么？        []
# 11                                        测试什么？        []
# 12      跟踪爱情中的人，看主观”爱的感觉“的量表，同时找脑信号correlation。        []
# 13                         不能给出causal relation。        []
# 14                                 Fisher 2010.        []
# 15                 分手后会有不同的感受。有人很痛苦，有人还感受甜蜜，有人。        []
# 16                             Aron et al 2005.        []
# 17                                    哪里应该会有激活？        []
# 18               会有激素调节；会有记忆脑区的区别（然而应该怎么区别？不确定）        []
# 19                                       奖赏回路活跃        []
# 20                     如果一个人的爱不求回报，还会有奖赏回路的激活吗？        []
# 21                     但是如果刚开始，是否有这个奖赏？还是逐渐形成的？        []
# 22  与生活其他的奖赏有什么关系？比如当你从工作中获得很多奖赏了，就不容易产生那么多的爱了？        []
# 23  只是说爱和友情的区别是奖赏回路，但是爱和工作还有别的差异，比如社会性，比如温柔的感觉。        []
# 24                                  爱和被爱，有什么区别？        []
# 25                        爱需要记忆支持吗，还是纯粹的一种生理状态？        []
# 26                     crush在什么年纪出现？为什么在那个时候出现？        []
# 27                        荷尔蒙不足够，还需要记忆和认知的基础。\t        []
# 28                         Young and Wang, 2004        []
# 29                               跟爱情没有关系，无法理解人的        []
# 30                           当这个激素消失后，会有什么行为变化？        []
# 31                            刺激大脑，主观汇报，是否感受到爱？        []
# 32                         汇报对某个人的爱，还是爱是一种整体的爱？        []

# %% [markdown]
# # To-Networkx

# %%
# generate text files for nodes
nodestr = '['
for knd in range(len(nodedf)):
    nd=nodedf.iloc[knd]
    nodestr = nodestr + '{"id":"%s","label":"%s","feature":"%s","content":"%s","reference":"%s",}'%(nd['id'],nd['label'],nd['feature'],nd['content'],nd['reference'])
nodestr = nodestr[:-1] #delete last comma
with open(filedir+'/node_curiosity.txt','w') as f:
    f.write(nodestr)

# generate text files for edges
edgestr = '['
for knd in range(len(edgedf)):
    ed=edgedf.iloc[knd]
    edgestr = edgestr + '{"id":"%s","label":"%s","start":"%s","end":"%s",}'%(ed['id'],ed['label'],ed['start'],ed['end'])
edgestr = edgestr[:-1] #delete last comma
with open(filedir+'/edge_curiosity.txt','w') as f:
    f.write(edgestr)

# %% [markdown]
# # To-Json
# obsolete: dictionary has changed so the code need to be revised

# %%
# styling for the package
rootcolor = 'orange'
anscolor = 'white'

jsonstr='\n"nodes":[\n'
for knode in range(len(nodedist['id'])):
    if nodedist['type'][knode]=='Q':
        jsonstr = jsonstr+'{"id":"%s","loaded":true,"style":{"label":"%s","fillColor":"%s"}},'%(nodedist['id'][knode],nodedist['label'][knode],rootcolor)
    elif nodedist['type'][knode]=='A':
        jsonstr = jsonstr+'{"id":"%s","loaded":true,"style":{"label":"%s","fillColor":"%s"}},'%(nodedist['id'][knode],nodedist['label'][knode],anscolor)
    else:
        set_trace()
        jsonstr = jsonstr+'{"id":"%s","loaded":true,"style":{"label":"%s"}},'%(node['id'],node['label'])
jsonstr = jsonstr+'],\n"links":[\n'

for link in fullnet:
    jsonstr = jsonstr+'{"id":"%s","from":"%s","to":"%s","type":"%s"},'%(link['eid'],link['from'],link['to'],link['edge'])
jsonstr = jsonstr[:-1]    

# todo: more details within each node to be differentiated. only for answers
# also, tiny problem: " in label, can't be normally read. should go to \" for some json thing.

# %%
with open('curiosity.json','w') as f:
    f.write(jsonstr)

# %%
nodedist.keys()
# Out:
# dict_keys(['type', 'id', 'label'])

# %%
nodedist=pd.DataFrame(nodedist)
nodedist
# Out:
#          id                                              label type
# 0    qd5030                                 What is curiosity?    Q
# 1   qd63348               What is the time scale of curiosity?    Q
# 2    ad5412                       lifelong (personality trait)    A
# 3   qd37294                       Is curiosity a stable trait?    Q
# 4   ad28604                                       Probably not    A
# 5   ad81555                                    seconds (state)    A
# 6   qd59535            What is the operationalized definition?    Q
# 7   ad32479                Melbourne Curiosity Inventory (MCI)    A
# 8   ad50922           State-Trait Personality Inventory (STPI)    A
# 9    ad3939                a motivator of exploratory behavior    A
# 10  qd73769   What constitutes the motivation for information?    Q
# 11  qd12544   What is the internal computation for motivation?    Q
# 12  ad17569                          Positive prediction error    A
# 13  ad13025                                  Learning progress    A
# 14  ad15814                                           Surprise    A
# 15  ad23230                            Interest-type curiosity    A
# 16  ad26419                         Deprivation-type curiosity    A
# 17  ad27605                             a need for information    A
# 18  qd86031            What kind of new information is seeken?    Q
# 19  qd93836                 What is the domain of information?    Q
# 20  ad60247                                 Physical curiosity    A
# 21  ad99637                               Perceptual curiosity    A
# 22  ad42889                                   Social curiosity    A
# 23  ad50632                   Epistemic/Intellectual curiosity    A
# 24  qd10787  What is the developmental order of different t...    Q
# 25  ad92099   physical, social, and intellectual curiosity ...    A
# 26  qd25743              What is the structure of information?    Q
# 27  qd57822     What is the number of topics being seeken for?    Q
# 28  ad79069                                  Breadth knowledge    A
# 29  ad24942                                    Depth knowledge    A
# 30  qd51771  What is the number of connection between infor...    Q
# 31  ad46378               Closely connected knowledge (hunter)    A
# 32   ad1618           Loosely connectedd knowledge (busy bees)    A
# 33  qd87143                  What is the purpose of curiosity?    Q
# 34  qd91280             Is it to increase or decrease arousal?    Q
# 35  ad57358                                  Diverse curiosity    A
# 36  ad77022                                 Specific curiosity    A
# 37  qd70869  Is it for gathering interesting information or...    Q
# 38  qd86521               Why is some information interesting?    Q
# 39  ad97269                          Epistemic curiosity scale    A
# 40  ad55376  Curiosity as a Feeling of Deprivation Scale (C...    A

# %% [markdown]
# # hand_input
# hand input each node-link pair

# %%
# input field
# question structures
defdims = [{'from':'What is the time scale of curiosity?',
               'to':['seconds/within trial','minutes/within trial', 'lifelong/personality trait']},#link list. todo: make it a type of object and add citations
           {'from':'What is the structure of knowledges being seeken for?',
               'to':['few connections/busybody','closely connected/hunter']},
           {'from':'What is the internal state computation that increases motivation?',
               'to':['learning progress','surprise','positive prediction error']}]
defobjs = [{'operdef':'self-reported curiosity level','paper':[],'dimlinks':['seconds/within trial','few connections/busybody']},
           {'operdef':'willingness to stick to the current game','dimlinks':['minutes/within trial','few connections/busybody'],'paper':['Bonawitz et al']},
           {'operdef':'KL divergence of belief state','dimlinks':['surprise'],'paper':[]}]

# %%
# convert to json for zoomcharts
allnodes = []
# add root note: the general concept we are talking about
rid='qd%d'%np.random.randint(100000)
allnodes.append({'label':'What is curiosity?','id':rid})
alllinks = []
for dim in defdims:
    # create nodes
    fid = 'qd%d'%np.random.randint(100000)
    fnode = {'label':dim['from'],'id':fid} #todo: add number repetition check
    allnodes.append(fnode)
    # add link from the rootnode
    alllinks.append({'label':'specification','id':'ld%d'%np.random.randint(100000),'from':rid,'to':fid})
    for tond in dim['to']:
        tid = 'a%d'%np.random.randint(100000)
        tonode = {'label':tond,'id':tid}
        allnodes.append(tonode)
        # add links
        alllinks.append({'label':'answer','id':'ld%d'%np.random.randint(100000),'from':fid,'to':tid})
nodedf = pd.DataFrame(allnodes)

#each operational definition object
for defob in defobjs:
    defid = 'ado%d'%np.random.randint(100000)
    allnodes.append({'label':defob['operdef'],'id':defid,'paper':defob['paper']})
    for kl in defob['dimlinks']:
        alllinks.append({'label':'operational_def','id':'lod%d'%np.random.randint(100000),
                        'from':nodedf['id'].iloc[nodedf.index[nodedf['label']==kl][0]],
                        'to':defid})

# styling
rootcolor = 'orange'
anscolor = 'white'

# %%
# translate to json
print("\nnode:\n")
for node in allnodes:
    if node['id']==rid:
        print('{"id":"%s","loaded":true,"style":{"label":"%s","fillColor":"%s"}},'%(node['id'],node['label'],rootcolor))
    elif node['id'][0]=='a':
        print('{"id":"%s","loaded":true,"style":{"label":"%s","fillColor":"%s"}},'%(node['id'],node['label'],anscolor))
    else:
        print('{"id":"%s","loaded":true,"style":{"label":"%s"}},'%(node['id'],node['label']))
print("\nlinks:\n")
for link in alllinks:
    print('{"id":"%s","from":"%s","to":"%s","type":"%s"},'%(link['id'],link['from'],link['to'],link['label']))
# Out:
# node:
#
# {"id":"qd39020","loaded":true,"style":{"label":"What is curiosity?","fillColor":"orange"}},
# {"id":"qd68905","loaded":true,"style":{"label":"What is the time scale of curiosity?"}},
# {"id":"a60280","loaded":true,"style":{"label":"seconds/within trial","fillColor":"white"}},
# {"id":"a79023","loaded":true,"style":{"label":"minutes/within trial","fillColor":"white"}},
# {"id":"a90009","loaded":true,"style":{"label":"lifelong/personality trait","fillColor":"white"}},
# {"id":"qd75943","loaded":true,"style":{"label":"What is the structure of knowledges being seeken for?"}},
# {"id":"a67943","loaded":true,"style":{"label":"few connections/busybody","fillColor":"white"}},
# {"id":"a4582","loaded":true,"style":{"label":"closely connected/hunter","fillColor":"white"}},
# {"id":"qd42158","loaded":true,"style":{"label":"What is the internal state computation that increases motivation?"}},
# {"id":"a50961","loaded":true,"style":{"label":"learning progress","fillColor":"white"}},
# {"id":"a45237","loaded":true,"style":{"label":"surprise","fillColor":"white"}},
# {"id":"a56473","loaded":true,"style":{"label":"positive prediction error","fillColor":"white"}},
# {"id":"ado2935","loaded":true,"style":{"label":"self-reported curiosity level","fillColor":"white"}},
# {"id":"ado9435","loaded":true,"style":{"label":"willingness to stick to the current game","fillColor":"white"}},
# {"id":"ado23948","loaded":true,"style":{"label":"KL divergence of belief state","fillColor":"white"}},
#
# links:
#
# {"id":"ld30565","from":"qd39020","to":"qd68905","type":"specification"},
# {"id":"ld52809","from":"qd68905","to":"a60280","type":"answer"},
# {"id":"ld13498","from":"qd68905","to":"a79023","type":"answer"},
# {"id":"ld16370","from":"qd68905","to":"a90009","type":"answer"},
# {"id":"ld88651","from":"qd39020","to":"qd75943","type":"specification"},
# {"id":"ld3583","from":"qd75943","to":"a67943","type":"answer"},
# {"id":"ld55037","from":"qd75943","to":"a4582","type":"answer"},
# {"id":"ld65812","from":"qd39020","to":"qd42158","type":"specification"},
# {"id":"ld72598","from":"qd42158","to":"a50961","type":"answer"},
# {"id":"ld3121","from":"qd42158","to":"a45237","type":"answer"},
# {"id":"ld31591","from":"qd42158","to":"a56473","type":"answer"},
# {"id":"lod94291","from":"a60280","to":"ado2935","type":"operational_def"},
# {"id":"lod58238","from":"a67943","to":"ado2935","type":"operational_def"},
# {"id":"lod53927","from":"a79023","to":"ado9435","type":"operational_def"},
# {"id":"lod53111","from":"a67943","to":"ado9435","type":"operational_def"},
# {"id":"lod114","from":"a45237","to":"ado23948","type":"operational_def"},

# %%
# translate to table
fulltable = []
opdf = pd.DataFrame(defobjs,index=[ob['operdef'] for ob in defobjs]) # temp: check dataframe
for dim in defdims:
    table = {}
    for prop in dim['to']:
        x = np.zeros(len(opdf),dtype=int)
        for k in range(len(opdf)):
            if prop in opdf.iloc[k]['dimlinks']:
                x[k]=1
        table[prop]=x
    fulltable.append({'dim':dim['from'],'table':pd.DataFrame(table,index=opdf.index)})

# %%
fulltable[0]['table']
# Out:
#                                           lifelong/personality trait  \
# self-reported curiosity level                                      0
# willingness to stick to the current game                           0
# KL divergence of belief state                                      0
#
#                                           minutes/within trial  \
# self-reported curiosity level                                0
# willingness to stick to the current game                     1
# KL divergence of belief state                                0
#
#                                           seconds/within trial
# self-reported curiosity level                                1
# willingness to stick to the current game                     0
# KL divergence of belief state                                0
